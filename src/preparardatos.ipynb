# %%
import pandas as pd

def preparar_datos():
    # Leer los datos
    df_abiertos = pd.read_csv('data/raw/datos_abiertos_2026_01.csv')
    df_nomenclatura = pd.read_csv('data/raw/nomenclatura_2026_01.csv')

    # Limpieza y transformación
    #df_viajes = df_viajes.drop(columns=['columna_innecesaria_1', 'columna_innecesaria_2'])
    
    #df_viajes = df_viajes.rename(columns={'id_origen': 'estacion_id'})
    #df_estaciones = df_estaciones.rename(columns={'id': 'estacion_id'})

    # Integración (Merge)
    #df_integrado = pd.merge(df_viajes, df_estaciones, on='estacion_id', how='left')

    # Guardar el archivo procesado
    #df_integrado.to_csv('data/processed/datos_integrados.csv', index=False)
    #print("Datos procesados e integrados exitosamente en data/processed/datos_integrados.csv")

if __name__ == '__main__':
    preparar_datos()
